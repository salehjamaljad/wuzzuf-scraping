# %%
# importing libraries
from bs4 import BeautifulSoup
import requests
import datetime
import csv
import time
import pandas as pd

# %%
# creating the file and its headers
header=['title','applicants','requirements','link']

with open('wuzzufanalystandresearch.csv','w',newline='',encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(header)

# %%
links=[]
def append_links(url):
    '''
    this function takes the page link as argument and returns all the products links in that page. 
    '''
    headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Safari/537.36"}
    try:
        page=requests.get(url,headers=headers,timeout=30)
    except requests.exceptions.ReadTimeout:
        print('error')
    except requests.exceptions.ConnectionError:
        print('c error')
    page=requests.get(url,headers=headers,timeout=30)
    soup1= BeautifulSoup(page.content,'html.parser')
    soup2=BeautifulSoup(soup1.prettify(),'html.parser')
    for link in soup2.find_all('a',attrs={"class": "css-o171kl",'rel':'noreferrer','target':'_blank'}):
        links.append('https://wuzzuf.net'+link.get('href'))

# %%
p=0
mains=[]
main_page=f'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start={p}'
headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Safari/537.36"}
page=requests.get(main_page,headers=headers,verify=False,timeout=30)
soup1= BeautifulSoup(page.content,'html.parser')
soup2=BeautifulSoup(soup1.prettify(),'html.parser')
for x in range(0,14): # the range is the number of pages
    main_page=f'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start={p}'
    mains.append(main_page)
    append_links(main_page)
    p+=1
# Out:
# C:\Users\co.magic\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'wuzzuf.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
print(p)
# Out:
# 14

# %%
print(len(mains))
print(mains)
# Out:
# 14
# ['https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=0', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=1', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=2', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=3', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=4', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=5', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=6', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=7', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=8', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=9', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=10', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=11', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=12', 'https://wuzzuf.net/a/Analyst-Research-Jobs-in-Egypt?start=13']

# %%
mains = list(dict.fromkeys(mains))
print(len(mains))
# Out:
# 14

# %%
links = list(dict.fromkeys(links))
print(len(links))
# Out:
# 267

# %%
links[0]
# Out:
# 'https://wuzzuf.net/jobs/p/XWGgeicMfJ7g-Software-Architect-Icity-Cairo-Egypt?o=1&l=bp&t=bj&bpv=np&a=Analyst-Research-Jobs-in-Egypt'

# %%
def appendjob(link):
    '''
    this function takes the product link as an argument and returns the title, the price and the link of the product.
    '''
    headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Safari/537.36"}
    try:
        page = requests.get(link,headers=headers,verify=False, timeout=30)
        soup1 = BeautifulSoup(page.content,'html.parser')
        soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
    except requests.exceptions.ConnectionError:
        link=links[i+1]
        page = requests.get(link,headers=headers,verify=False, timeout=30)
        soup1 = BeautifulSoup(page.content,'html.parser')
        soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
        print('con error')
    except requests.exceptions.ReadTimeout:
        link=links[i+1]
        print('t error')
    try:
        title=soup2.find('h1', {'class':'css-f9uh36'}).get_text()
        title=title.strip()
    except AttributeError:
        title='N/A'
    except ConnectionError :
        title='N/A'
    except UnboundLocalError:
        title='N/A'
    try:
        applicants=soup2.find('strong', {'class':'css-u1gwks'}).get_text()
        applicants=int(applicants)
    except AttributeError:
        applicants='N/A'
    except ConnectionError:
        applicants='N/A'
    except UnboundLocalError:
        applicants='N/A'
    try:
        requirements=soup2.find('div', {'class':'css-1t5f0fr'})
    except AttributeError:
        requirements='N/A'
    except ConnectionError:
        requirements='N/A'
    except UnboundLocalError:
        requirements='N/A'
    link=links[i]
    data=[title,applicants,requirements,link]
    with open('wuzzufanalystandresearch.csv','a+',newline='',encoding='UTF8') as f:
        writer=csv.writer(f)
        writer.writerow(data)

# %%
# loop over products
i=0
for link in links:
    appendjob(links[i])
    i+=1
# Out:
# C:\Users\co.magic\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'wuzzuf.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\co.magic\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'wuzzuf.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
print(i)
# Out:
# 242

# %%
i=242
for link in links:
    appendjob(links[i])
    i+=1
# Out:
# C:\Users\co.magic\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'wuzzuf.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\co.magic\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'wuzzuf.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...
